# %%
using CairoMakie, CSV, DataFrames, Pipe, StatsKit

# %%
all_csv = [i for i in readdir() if occursin(".csv", i)]
all_df = [CSV.read(j, DataFrame, header=true) for j in all_csv]
long_df = outerjoin(all_df..., on=intersect([names(j) for j in all_df]...))
@pipe long_df |> select(_,[:itr,:loss]) |> sort(_,:itr) |> lines(eachcol(_)...)
ax = current_axis()
xlims!(ax, 000,12000)
current_figure()

# %%
@pipe ceil.(long_df[:,:itr] / 100) |> 
    trunc.(Int64,_) |> 
    DataFrame(itr=long_df[:,:itr],index = _) |> 
    innerjoin(_, long_df, on=:itr) |> groupby(_,:index)  |> 
    combine(_, :loss => mean) |> lines(eachcol(_)...)

# %%
@pipe long_df |> filter(:itr => x -> x%100==1, _) |> sort(_, :loss)
# Out:
# 118×3 DataFrame
#  Row │ Column1  itr      loss
#      │ Int64    Float64  Float64
# ─────┼────────────────────────────
#    1 │       0  11501.0  0.821612
#    2 │       0  11301.0  0.835424
#    3 │       0  11201.0  0.838176
#    4 │       0  11601.0  0.852067
#    5 │       0  10601.0  0.862034
#    6 │       0  11701.0  0.877111
#    7 │       0  11001.0  0.884648
#    8 │       0  10201.0  0.894598
#    9 │       0   9901.0  0.912301
#   10 │       0   9801.0  0.917232
#   11 │       0  10901.0  0.927647
#   ⋮  │    ⋮        ⋮        ⋮
#  109 │       0   1801.0  1.48339
#  110 │       0    801.0  1.53712
#  111 │       0   1201.0  1.5424
#  112 │       0   1101.0  1.58337
#  113 │       0    601.0  1.62526
#  114 │       0    401.0  1.82195
#  115 │       0    301.0  1.90701
#  116 │       0    201.0  2.25759
#  117 │       0    101.0  2.34204
#  118 │       0      1.0  2.84545
#                    97 rows omitted

# %%
print(size(long_df))
# Out:
# (11700, 3)

# %%
@pipe long_df |> sort(_, :loss) |> first(_,10)
# Out:
# 10×3 DataFrame
#  Row │ Column1  itr      loss
#      │ Int64    Float64  Float64
# ─────┼────────────────────────────
#    1 │      26  11327.0  0.796871
#    2 │       4  11705.0  0.805089
#    3 │      89  10890.0  0.807218
#    4 │      27  11328.0  0.811407
#    5 │      29  11330.0  0.813832
#    6 │      30  11331.0  0.814238
#    7 │       5  11606.0  0.814586
#    8 │      33  11134.0  0.815369
#    9 │      28  11329.0  0.817021
#   10 │       8  11609.0  0.817705

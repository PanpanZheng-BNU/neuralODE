# %%
import torch
from torch import nn, optim, tensor, Tensor
from torchdiffeq import odeint, odeint_adjoint
from torchdyn.datasets import ToyDataset
import matplotlib.pyplot as plt
from matplotlib import animation
import progressbar
import pandas as pd
import os

# %%
n_samples = 2 ** 14 # the number of samples
n_gaussians = 6 # the number of Gaussians

X, _ = ToyDataset().generate(n_samples // n_gaussians,
                              'spheres',
                             noise=8e-2,
                              # n_gaussians=n_gaussians,
                              # std_gaussians=.5,
                              dim=2)


X = (X - X.mean()) / X.std()

plt.figure(figsize=(5, 5))
plt.scatter(X[:,0], X[:,1], c='black', alpha=0.2, s=1.)

# %%
def autograd_trace(x_out, x_in):
    """
    `autograd_trace`:(`x_out`, `x_in`): compute the trace of the Jacobian of `x_out` w.r.t. `x_in` using autograd.
    """
    trJ = 0.
    for i in range(x_in.shape[1]):
        trJ += torch.autograd.grad(x_out[:,i].sum(), x_in, create_graph=True)[0].contiguous()[:,i].contiguous()
    return trJ.contiguous()

class CNF(nn.Module):
    def __init__(self, in_out_dim, hidden_dim, width):
        super().__init__()
        self.in_out_dim = in_out_dim
        self.hidden_dim = hidden_dim
        self.width = width
        self.planar = Planar(in_out_dim, hidden_dim, width)

    def forward(self, t, states):
        z = states[0]
        logp_z = states[1]

        batchsize = z.shape[0]

        with torch.set_grad_enabled(True):
            z.requires_grad_(True)

            w,u,b = self.planar(t)

            Z = torch.unsqueeze(z,0).repeat(self.width, 1,1)

            h = torch.tanh(torch.matmul(Z,w) + b)
            dz_dt = torch.matmul(h, u).mean(0)

            dlogp_z_dt = -autograd_trace(dz_dt, z).view(batchsize, 1)

        return (dz_dt, dlogp_z_dt)

class Planar(nn.Module):
    """
    Construct a net according to the Planar Flow: return the params of the flow:
    u, w, b
    """
    def __init__(self, in_out_dim, hidden_dim, width):
        super().__init__()

        blocksize = width * in_out_dim

        self.fc1 = nn.Linear(1, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, 3 * blocksize + width)

        self.in_out_dim = in_out_dim
        self.hidden_dim = hidden_dim
        self.width = width
        self.blocksize = blocksize

    def forward(self, t):
        params = t.reshape(1,1)
        params = torch.tanh(self.fc1(params))
        params = torch.tanh(self.fc2(params))
        params = self.fc3(params)
        params = params.reshape(-1)

        w = params[:self.blocksize].reshape(self.width, self.in_out_dim, 1)
        u = params[self.blocksize:2*self.blocksize].reshape(self.width, 1,self.in_out_dim)
        g = params[2*self.blocksize:3*self.blocksize].reshape(self.width, 1,self.in_out_dim)
        u = u*torch.sigmoid(g)

        b = params[3 * self.blocksize:].reshape(self.width,1,1)
        return [w,u,b]

# %%
'cus' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
# Out:
# 'mps'

# %%
t0 = 0
t1 = 10
device = torch.device(
    'cuda' if torch.cuda.is_available() else 'cpu'
)

func = CNF(in_out_dim=2, hidden_dim=64, width=3).to(device)
optimizer = optim.Adam(func.parameters(), lr=5e-3)
p_z0 = torch.distributions.MultivariateNormal(
    loc=torch.tensor([0.0, 0.0]).to(device),
    covariance_matrix=torch.tensor([[1, 0.0], [0.0, 1]]).to(device)
)


df = pd.DataFrame(columns=["itr", "loss"])

# %%
checkpoint = torch.load('spheres3100.pt', map_location=device)
checkpoint["loss"]
func.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
func.eval()
# Out:
# CNF(
#   (planar): Planar(
#     (fc1): Linear(in_features=1, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=21, bias=True)
#   )
# )

# %%
z0_vis = p_z0.sample([10000])
logp_z0_vis = torch.zeros(10000).to(device)
t = torch.linspace(t0,t1,500)

z1_vis = odeint(func,
                (z0_vis,logp_z0_vis),
                # torch.Tensor([t0,t1]),
                t, 
                atol = 1e-5,
                rtol = 1e-5,
                method ='dopri5'
                )[0]

# %%
def animate(i):
    ax.cla()
    if i < 30:
        ax.scatter(*X.T, s=1.)
        ax.scatter(*z1_vis[0].detach().cpu().T, s=1., alpha=0.8)
    elif 30 <= i < 530:
        ax.scatter(*X.T, s=1.)
        ax.scatter(*z1_vis[i-30].detach().cpu().T, s=1., alpha=0.8)
    else:
        ax.scatter(*X.T, s=1.)
        ax.scatter(*z1_vis[-1].detach().cpu().T, s=1., alpha=0.8)
        
    ax.set_xlim(-4,4)
    ax.set_ylim(-4,4)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ani = animation.FuncAnimation(fig, animate, frames=560)
writer = animation.PillowWriter(fps=30,
                                # metadata=dict(artist='Me'),
                               )
ani.save('spheres.gif', writer = writer)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.scatter(*X.T, s=1.)
ax.scatter(*z1_vis[-1].detach().cpu().T, s=1., alpha=0.8)
ax.set_xlim(-4,4)
ax.set_ylim(-4,4)
# Out:
# (-4.0, 4.0)

# %%
r = r"\d+"

# %%
r
# Out:
# '\\d+'

# %%
[i for i in os.listdir() if ".pt" in i]
# Out:
# ['moons1700.pt',
#  'moons4000.pt',
#  'moons5600.pt',
#  'moons8300.pt',
#  'moons7600.pt',
#  'moons2100.pt',
#  'moons200.pt',
#  'moons3700.pt',
#  'moons6000.pt',
#  'moons6100.pt',
#  'moons300.pt',
#  'moons3600.pt',
#  'moons2000.pt',
#  'moons7700.pt',
#  'moons8200.pt',
#  'moons5700.pt',
#  'moons4100.pt',
#  'moons1600.pt',
#  'moons7000.pt',
#  'moons2700.pt',
#  'moons400.pt',
#  'moons3100.pt',
#  'moons6600.pt',
#  'moons1100.pt',
#  'moons4600.pt',
#  'moons5000.pt',
#  'moons800.pt',
#  'moons8500.pt',
#  'moons8400.pt',
#  'moons900.pt',
#  'moons5100.pt',
#  'moons4700.pt',
#  'moons1000.pt',
#  'moons8800.pt',
#  'moons6700.pt',
#  'moons500.pt',
#  'moons3000.pt',
#  'moons2600.pt',
#  'moons7100.pt',
#  'moons6400.pt',
#  'moons3300.pt',
#  'moons600.pt',
#  'moons2500.pt',
#  'moons7200.pt',
#  'moons4800.pt',
#  'moons6800.pt',
#  'moons8700.pt',
#  'moons2900.pt',
#  'moons5200.pt',
#  'moons4400.pt',
#  'moons1300.pt',
#  'moons1200.pt',
#  'moons4500.pt',
#  'moons5300.pt',
#  'moons2800.pt',
#  'moons6900.pt',
#  'moons8600.pt',
#  'moons4900.pt',
#  'moons7300.pt',
#  'moons2400.pt',
#  'moons3200.pt',
#  'moons700.pt',
#  'moons6500.pt',
#  'moons8100.pt',
#  'moons3900.pt',
#  'moons7800.pt',
#  'moons5400.pt',
#  'moons4200.pt',
#  'moons1500.pt',
#  'moons6200.pt',
#  'moons3500.pt',
#  'moons2300.pt',
#  'moons7400.pt',
#  'moons5800.pt',
#  'moons1900.pt',
#  'moons1800.pt',
#  'moons5900.pt',
#  'moons7500.pt',
#  'moons2200.pt',
#  'moons3400.pt',
#  'moons100.pt',
#  'moons6300.pt',
#  'moons1400.pt',
#  'moons4300.pt',
#  'moons5500.pt',
#  'moons7900.pt',
#  'moons3800.pt',
#  'moons8000.pt']

# %%
n_gaussians = 6
def get_batch(num_samples):
    points, _ = ToyDataset().generate(n_samples=num_samples, noise=2e-1, dataset_type='moons')

    X = ((points - points.mean()) / points.std()).type(torch.float32).to(device)
    logp_diff_t1 = torch.zeros(X.size(0), 1).type(torch.float32).to(device)

    return (X,logp_diff_t1)

# %%
for itr in progressbar.progressbar(range(checkpoint['epoch']+1, checkpoint['epoch'] + 2000 + 1)):
    optimizer.zero_grad()

    x, logp_diff_t1 = get_batch(5000)
    z_t, logp_diff_t = odeint(
                func,
                (x, logp_diff_t1),
                torch.tensor([t1, t0]).type(torch.float32).to(device),
                atol=1e-5,
                rtol=1e-5,
                method='dopri5',
            )
    z_t0, logp_diff_t0 = z_t[-1], logp_diff_t[-1]

    # logp_x = p_z0.log_prob(z_t0).to(device) - logp_diff_t0.view(-1)
    # loss = -logp_x.mean(0)
    C = 1/2 * z_t0.norm(dim=1,p=2) ** 2 + logp_diff_t0.view(-1) + torch.log(Tensor([2 * torch.pi]).to(device))
    loss = C.mean(0)


    loss.backward()
    optimizer.step()
    df.loc[len(df.index)] = [itr, loss.item()]

    # if itr % 100 == 0:
      # save_checkpoint(func, itr, optimizer, loss.item(), PATH=os.path.join(p2drive,"moons","moons{}.pt".format(itr)))
      # df.to_csv(os.path.join(p2drive,"moons","output_{}.csv".format(itr)))
      # df = pd.DataFrame(columns=["itr", "loss"])
# Out:
#   1% (35 of 2000) |                      | Elapsed Time: 0:00:37 ETA:   0:35:02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[216], line 5
#       2 optimizer.zero_grad()
#       4 x, logp_diff_t1 = get_batch(5000)
# ----> 5 z_t, logp_diff_t = odeint(
#       6             func,
#       7             (x, logp_diff_t1),
#       8             torch.tensor([t1, t0]).type(torch.float32).to(device),
#       9             atol=1e-5,
#      10             rtol=1e-5,
#      11             method='dopri5',
#      12         )
#      13 z_t0, logp_diff_t0 = z_t[-1], logp_diff_t[-1]
#      15 # logp_x = p_z0.log_prob(z_t0).to(device) - logp_diff_t0.view(-1)
#      16 # loss = -logp_x.mean(0)
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchdiffeq/_impl/odeint.py:77, in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      74 solver = SOLVERS[method](func=func, y0=y0, rtol=rtol, atol=atol, **options)
#      76 if event_fn is None:
# ---> 77     solution = solver.integrate(t)
#      78 else:
#      79     event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchdiffeq/_impl/solvers.py:30, in AdaptiveStepsizeODESolver.integrate(self, t)
#      28 self._before_integrate(t)
#      29 for i in range(1, len(t)):
# ---> 30     solution[i] = self._advance(t[i])
#      31 return solution
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchdiffeq/_impl/rk_common.py:194, in RKAdaptiveStepsizeODESolver._advance(self, next_t)
#     192 while next_t > self.rk_state.t1:
#     193     assert n_steps < self.max_num_steps, 'max_num_steps exceeded ({}>={})'.format(n_steps, self.max_num_steps)
# --> 194     self.rk_state = self._adaptive_step(self.rk_state)
#     195     n_steps += 1
#     196 return _interp_evaluate(self.rk_state.interp_coeff, self.rk_state.t0, self.rk_state.t1, next_t)
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchdiffeq/_impl/rk_common.py:255, in RKAdaptiveStepsizeODESolver._adaptive_step(self, rk_state)
#     250         dt = t1 - t0
#     252 # Must be arranged as doing all the step_t handling, then all the jump_t handling, in case we
#     253 # trigger both. (i.e. interleaving them would be wrong.)
# --> 255 y1, f1, y1_error, k = _runge_kutta_step(self.func, y0, f0, t0, dt, t1, tableau=self.tableau)
#     256 # dtypes:
#     257 # y1.dtype == self.y0.dtype
#     258 # f1.dtype == self.y0.dtype
#    (...)
#     263 #                     Error Ratio                      #
#     264 ########################################################
#     265 error_ratio = _compute_error_ratio(y1_error, self.rtol, self.atol, y0, y1, self.norm)
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchdiffeq/_impl/rk_common.py:76, in _runge_kutta_step(func, y0, f0, t0, dt, t1, tableau)
#      74         perturb = Perturb.NONE
#      75     yi = y0 + torch.sum(k[..., :i + 1] * (beta_i * dt), dim=-1).view_as(f0)
# ---> 76     f = func(ti, yi, perturb=perturb)
#      77     k = _UncheckedAssign.apply(k, f, (..., i + 1))
#      79 if not (tableau.c_sol[-1] == 0 and (tableau.c_sol[:-1] == tableau.beta[-1]).all()):
#      80     # This property (true for Dormand-Prince) lets us save a few FLOPs.
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchdiffeq/_impl/misc.py:189, in _PerturbFunc.forward(self, t, y, perturb)
#     186 else:
#     187     # Do nothing.
#     188     pass
# --> 189 return self.base_func(t, y)
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchdiffeq/_impl/misc.py:159, in _ReverseFunc.forward(self, t, y)
#     158 def forward(self, t, y):
# --> 159     return self.mul * self.base_func(-t, y)
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchdiffeq/_impl/misc.py:138, in _TupleFunc.forward(self, t, y)
#     137 def forward(self, t, y):
# --> 138     f = self.base_func(t, _flat_to_shape(y, (), self.shapes))
#     139     return torch.cat([f_.reshape(-1) for f_ in f])
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[3], line 32, in CNF.forward(self, t, states)
#      29     Z = torch.unsqueeze(z,0).repeat(self.width, 1,1)
#      31     h = torch.tanh(torch.matmul(Z,w) + b)
# ---> 32     dz_dt = torch.matmul(h, u).mean(0)
#      34     dlogp_z_dt = -autograd_trace(dz_dt, z).view(batchsize, 1)
#      36 return (dz_dt, dlogp_z_dt)
#
# KeyboardInterrupt:

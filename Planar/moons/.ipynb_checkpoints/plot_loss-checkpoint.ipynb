# %%
using CairoMakie, CSV, DataFrames, Pipe, StatsKit

# %%
all_csv = [i for i in readdir() if occursin(".csv", i)]
all_df = [CSV.read(j, DataFrame, header=true) for j in all_csv]
long_df = outerjoin(all_df..., on=intersect([names(j) for j in all_df]...))
@pipe long_df |> select(_,[:itr,:loss]) |> sort(_,:itr) |> lines(eachcol(_)...)
ax = current_axis()
xlims!(ax, 000,10000)
current_figure()

# %%
@pipe ceil.(long_df[:,:itr] / 100) |> 
    trunc.(Int64,_) |> 
    DataFrame(itr=long_df[:,:itr],index = _) |> 
    innerjoin(_, long_df, on=:itr) |> groupby(_,:index)  |> 
    combine(_, :loss => mean) |> lines(eachcol(_)...)

# %%
@pipe long_df |> filter(:itr => x -> x%100==1, _) |> sort(_, :loss)
# Out:
# 100×3 DataFrame
#  Row │ Column1  itr      loss
#      │ Int64    Float64  Float64
# ─────┼────────────────────────────
#    1 │       0   9901.0  0.912301
#    2 │       0   9801.0  0.917232
#    3 │       0   9701.0  0.934725
#    4 │       0   8701.0  0.949821
#    5 │       0   9401.0  0.951355
#    6 │       0   8601.0  0.960115
#    7 │       0   9601.0  0.979632
#    8 │       0   7201.0  0.980292
#    9 │       0   7501.0  0.981561
#   10 │       0   8001.0  0.991723
#   11 │       0   9001.0  1.00026
#   ⋮  │    ⋮        ⋮        ⋮
#   91 │       0   1801.0  1.48339
#   92 │       0    801.0  1.53712
#   93 │       0   1201.0  1.5424
#   94 │       0   1101.0  1.58337
#   95 │       0    601.0  1.62526
#   96 │       0    401.0  1.82195
#   97 │       0    301.0  1.90701
#   98 │       0    201.0  2.25759
#   99 │       0    101.0  2.34204
#  100 │       0      1.0  2.84545
#                    79 rows omitted

# %%
print(size(long_df))
# Out:
# (10000, 3)

# %%
@pipe long_df |> sort(_, :loss) |> first(_,10)
# Out:
# 10×3 DataFrame
#  Row │ Column1  itr      loss
#      │ Int64    Float64  Float64
# ─────┼────────────────────────────
#    1 │      49   9650.0  0.854202
#    2 │      48   9749.0  0.85489
#    3 │      34   9535.0  0.857373
#    4 │      65   9466.0  0.862116
#    5 │      65   9866.0  0.862259
#    6 │      31   9832.0  0.863254
#    7 │      45   9646.0  0.865627
#    8 │      46   9747.0  0.86564
#    9 │      24   9925.0  0.868268
#   10 │      61   9862.0  0.870924
